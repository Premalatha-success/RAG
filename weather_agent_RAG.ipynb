# %%
# !pip install -q smolagents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 3.9 MB/s eta 0:00:00

# %%
# !pip install markdownify duckduckgo-search spaces gradio-tools langchain langchain-community langchain-huggingface faiss-cpu --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 68.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 107.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 3.8 MB/s eta 0:00:00

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from smolagents import CodeAgent, HfApiModel, DuckDuckGoSearchTool

# %%
from smolagents import InferenceClientModel

model_id = "Qwen/Qwen2.5-72B-Instruct"
model = InferenceClientModel(model_id)

# %%
from smolagents import CodeAgent, ToolCallingAgent, DuckDuckGoSearchTool, VisitWebpageTool

web_agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool(), VisitWebpageTool()], model=model)

# %%
# Now, use web_agent directly
query = "What's the weather like inChennai today?"

result = web_agent.run(query)
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What's the weather like inChennai today?                                                                        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-72B-Instruct ──────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': 'weather in Chennai today'}                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |Chennai, Tamil Nadu, India Weather Forecast |
# AccuWeather](https://www.accuweather.com/en/in/chennai/206671/weather-forecast/206671)
# Chennai, Tamil Nadu, India Weather Forecast, with current conditions, wind, air quality, and what to expect for the
# next 3 days.
#
# |Tamil Nadu Weather: 17 Districts To Get Heavy Rains Today ... -
# Oneindia](https://www.oneindia.com/chennai/tamil-nadu-weather-17-districts-to-get-heavy-rains-today-light-showers-i
# n-chennai-predicted-for-2-4157611.html)
# Tamil Nadu Weather: 17 Dists To Get Heavy Rains Today; Light Showers In Chennai Predicted For 2 Days By ... Top 24
# hours Rainfall in State and Chennai ending 8.30 am on 19.05.2025 is enclosed."
#
# |Weather Today for Chennai, Tamil Nadu, India |
# AccuWeather](https://www.accuweather.com/en/in/chennai/206671/weather-today/206671)
# Expect a hot and hazy day in Chennai with a high of 98°F and a low of 82°F. There is a 25% chance of precipitation
# and a 6% chance of thunderstorms. See hourly, daily and monthly forecasts, sunrise and sunset times, and
# temperature history.
#
# |Tamil Nadu set for heavy rainfall across multiple districts; Chennai to
# ...](https://english.mathrubhumi.com/news/india/tamil-nadu-heavy-rain-alert-chennai-weather-today-xaj3e39p)
# Chennai weather outlook. In Chennai and its suburbs, residents can expect partly cloudy skies with light to
# moderate rain in some areas over the next 48 hours. The maximum temperature is ...
#
# |Chennai local weather (live): today, hourly
# weather](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today)
# Get the hourly weather forecast for Chennai today, Sunday, 20 April 2025. Expect very hot temperatures reaching
# 91°F, clear skies and no chance of rain.
#
# |Today's Weather in Chennai - Hourly Forecast and
# Conditions](https://www.easeweather.com/asia/india/tamil-nadu/chennai/today)
# Find out the current and future weather conditions in Chennai, India, for today. See the temperature, wind, rain,
# UV index, and more for each hour of the day.
#
# |Chennai Weather Forecast 18 May 2025 - Times of
# India](https://timesofindia.indiatimes.com/weather/chennai-weather-forecast-today/600017)
# Today's Weather in Chennai: In Chennai today, the weather is expected to be Mostly Cloudy with a maximum
# temperature of 28°C and a minimum of 24°C. Sunrise in Chennai is set for 06:35 AM and ...
#
# |Weather today - Chennai, India](https://www.weather-atlas.com/en/india/chennai)
# Find out the current temperature, feels like, wind, humidity, and precipitation in Chennai. See the hourly weather
# forecast for today, including sunrise, sunset, and daylight hours.
#
# |Chennai Weather Forecast](https://www.weather-forecast.com/locations/Madras/forecasts/latest)
# The Long-range 12 day forecast also includes detail for Chennai weather today. Live weather reports from Chennai
# weather stations and weather warnings that include risk of thunder, high UV index and forecast gales. See the links
# below the 12-day Chennai weather forecast table for other cities and towns nearby along with weather conditions for
# ...
#
# |Chennai, Tamil Nadu Weather - The Weather
# Channel](https://weather.com/en-IN/weather/hourbyhour/l/Chennai+Tamil+Nadu?canonicalCityId=f36cfd8e1ba9dcb5443299b6
# cd05869a789939c26f3fef59f888a25c03bdfced)
# Hourly Local Weather Forecast, weather conditions, precipitation, dew point, humidity, wind from Weather.com and
# The Weather Channel
# [Step 1: Duration 2.47 seconds| Input tokens: 1,282 | Output tokens: 23]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'visit_webpage' with arguments: {'url':                                                           │
# │ 'https://www.accuweather.com/en/in/chennai/206671/weather-today/206671'}                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Error fetching the webpage: 403 Client Error: Forbidden for url:
# https://www.accuweather.com/en/in/chennai/206671/weather-today/206671
# [Step 2: Duration 7.43 seconds| Input tokens: 3,570 | Output tokens: 71]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error while parsing tool call from model output: The JSON blob you used is invalid due to the following error:
# Expecting property name enclosed in double quotes: line 1 column 2 (char 1).
# JSON blob was: Called Tool: 'visit_webpage' with arguments: {'url':
# 'https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today'}
# Calling tools:
# , decoding failed on that specific part of the blob:
# ''.
# [Step 3: Duration 1.50 seconds| Input tokens: 6,040 | Output tokens: 112]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'visit_webpage' with arguments: {'url':                                                           │
# │ 'https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today'}                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Chennai local weather (live): today, hourly weather
#
# |!|weather25.com](https://www.weather25.com/images/weather25-black.svg "weather25.com")](https://www.weather25.com
# "weather25.com")
#
# |United States](https://www.weather25.com/north-america/usa "Weather in United States")
# |England](https://www.weather25.com/europe/united-kingdom "Weather in England")
# |Australia](https://www.weather25.com/oceania/australia "Weather in Australia")
# |Canada](https://www.weather25.com/north-america/canada "Weather in Canada")
#
# °F     °C
#
# !|Search](https://res.weather25.com/images/icons/search_white_new.svg "Search")
#
# Chennai !|weather in India](https://res.weather25.com/images/r-flags/india.svg "weather in India")
#
# Weather today
#
# * |Overview](https://www.weather25.com/asia/india/tamil-nadu/chennai)
# * |14 Days](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=14)
# * |May](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=month&month=May)
# * |June](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=month&month=June)
# * |Long range](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=long-range)
# * |Today](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today)
# * |Tomorrow](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=tomorrow)
#
# !|Remove from your favorite locations](https://res.weather25.com/images/icons/filled-star.svg "Remove from your
# favorite locations") !|Add to my locations](https://res.weather25.com/images/icons/empty-star.svg "Add to my
# locations")
#
# !|Share](https://res.weather25.com/images/icons/share.svg "Share")
#
# 1. |Home](https://www.weather25.com)
# 2. |Asia](https://www.weather25.com/asia)
# 3. |!|weather in India](https://res.weather25.com/images/r-flags/india.svg "weather in
# India")India](https://www.weather25.com/asia/india)
# 4. |Tamil Nadu](https://www.weather25.com/asia/india/tamil-nadu)
# 5. |Chennai](https://www.weather25.com/asia/india/tamil-nadu/chennai)
# 6. |Today](/asia/india/tamil-nadu/chennai?page=today)
#
# Location was added to |My Locations](/my-locations)
#
# Location was removed from |My Locations](/my-locations)
#
# The local weather in Chennai today
# ==================================
#
# Tuesday, 20 May 2025
#
# The weather today in Chennai will be **very hot with temperatures reaching 31°C**. During the evening and night
# time the temperatures will drop to 29°C.
#
# For deep dive information check out our
# |hourly](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today#intervals-1) weather forecast for today
# down the page.
#
# !|Temperature]( "Temperature")
#
# Temperature
#
# 31° / 29°
#
# !|Chance of rain]( "Chance of rain")
#
# Chance of rain
#
# 100
#
# %
#
# !|Wind]( "Wind")
#
# Wind
#
# 18
#
# Km/h
#
# !|Humidity]( "Humidity")
#
# Humidity
#
# 74
#
# %
#
# Previous day
#
# 3 Hours Hour by Hour
#
# |Next day](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=tomorrow)
#
# |  | 00:00 | 03:00 | 06:00 | 09:00 | 12:00 | 15:00 | 18:00 | 21:00 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Temperature | 29°C | 29°C | 29°C | 30°C | 31°C | 31°C | 30°C | 30°C |
# | Weather | Partly cloudy Partly cloudy | Partly cloudy Partly cloudy | Light rain shower Light rain shower |
# Patchy rain possible Patchy rain possible | Cloudy Cloudy | Partly cloudy Partly cloudy | Clear Clear | Partly
# cloudy Partly cloudy |
# | Chance of rain | 0% | 0% | 100% | 100% | 0% | 0% | 0% | 0% |
# | Precipitation | 0 mm | 0 mm | 0.5 mm | 0.1 mm | 0 mm | 0 mm | 0 mm | 0 mm |
# | Humidity | 74% | 74% | 72% | 70% | 62% | 67% | 73% | 74% |
# | Wind | 15Km/h | 15Km/h | 10Km/h | 10Km/h | 8Km/h | 12Km/h | 15Km/h | 18Km/h |
# | Wind Gust | 21Km/h | 21Km/h | 14Km/h | 14Km/h | 11Km/h | 18Km/h | 22Km/h | 25Km/h |
# | Wind Degree | 250° Wind Degree | 249° Wind Degree | 279° Wind Degree | 359° Wind Degree | 10° Wind Degree | 105°
# Wind Degree | 150° Wind Degree | 189° Wind Degree |
# | Wind Direction | WSW | WSW | W | N | N | ESE | SSE | S |
# | Cloud Cover | 36% | 55% | 60% | 73% | 68% | 45% | 22% | 28% |
# | UV Index | 0 | 0 | 0 | 3 | 4 | 1 | 0 | 0 |
# | Visibility | 10 Km | 10 Km | 10 Km | 10 Km | 10 Km | 10 Km | 10 Km | 10 Km |
#
# Check Chennai's weather in other day
#
# Click on a day for an hourly weather forecast
#
# |Tuesday
#
# May 20
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 1.5 mm
#
# 31° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=today)|Wednesday
#
# May 21
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 2.3 mm
#
# 32° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=tomorrow)|Thursday
#
# May 22
#
# !|Thundery outbreaks possible]( "Thundery outbreaks possible")
#
# 5 mm
#
# 35° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-22)|Friday
#
# May 23
#
# !|Patchy light rain with thunder]( "Patchy light rain with thunder")
#
# 1.3 mm
#
# 35° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-23)|Saturday
#
# May 24
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 0.5 mm
#
# 36° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-24)|Sunday
#
# May 25
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 0 mm
#
# 34° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-25)|Monday
#
# May 26
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 0.3 mm
#
# 33° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-26)|Tuesday
#
# May 27
#
# !|Overcast]( "Overcast")
#
# 0 mm
#
# 33° / 29°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-27)|Wednesday
#
# May 28
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 0 mm
#
# 34° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-28)|Thursday
#
# May 29
#
# !|Patchy rain possible]( "Patchy rain possible")
#
# 0.5 mm
#
# 31° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-29)|Friday
#
# May 30
#
# !|Partly cloudy]( "Partly cloudy")
#
# 0 mm
#
# 36° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-30)|Saturday
#
# May 31
#
# !|Cloudy]( "Cloudy")
#
# 0 mm
#
# 36° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-05-31)|Sunday
#
# Jun 1
#
# !|Partly cloudy]( "Partly cloudy")
#
# 0 mm
#
# 36° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-06-01)|Monday
#
# Jun 2
#
# !|Light rain shower]( "Light rain shower")
#
# 0.8 mm
#
# 35° / 30°](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=day#date=2025-06-02) |Next
# Month >>](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=long-range)
#
# The weather in Chennai today - FAQ
# ----------------------------------
#
# What is the weather today in Chennai?
#
# The wather forecast for today in Chennai is mostly patchy rain possible.
#
# What is today's highest and lowest temperature in Chennai?
#
# The temperature today in Chennai will range between 29° and 31°.
#
# Will it be raining today in Chennai?
#
# The chance of rain today in Chennai is 100%.
#
# Will it be windy today in Chennai?
#
# The wind will blow between 8 Km/h to 18 Km/h today in Chennai.
#
# How many hours of sunlight today in Chennai?
#
# There will be 10.5 hours of sun today in Chennai.
#
# What time is the sunrise and sunset today in Chennai?
#
# The sun will rise at 05:43 and set at 18:28.
#
# Sunrise and sunset time in Chennai today
# ----------------------------------------
#
# What time is the sunset and sunrise in Chennai today? The sun will rise at 05:43 and will set at 18:28. There will
# be 10.5 hours of sunlight in Chennai.
#
# !|Sunrise]( "Sunrise")
#
# Sunrise
#
# 05:43
#
# !|Sunset]( "Sunset")
#
# Sunset
#
# 18:28
#
# Chennai today weather
# ---------------------
#
# Morning !|Patchy rain possible]( "Patchy rain possible")
#
# The temperature in Chennai today in the early morning is 29°C.
#
# If you take into account factors such as wind, humidity and other weather conditions, the temperatures can feel
# like 33°C.
#
# The chance of rain in Chennai in the morning is 100%, and the wind will blow at 10km/h.
#
# Noon !|Cloudy]( "Cloudy")
#
# The temperature in Chennai today at noon time is 31°C and it will feel like 36°C. The humidity will be around 62%
# with wind speed of 8km/h.
#
# Evening !|Clear]( "Clear")
#
# The temperature in Chennai today's evening will get to 31°C.
#
# The chance of rain in Chennai in the evening time is 0%, with wind speed of 12km/h.
#
# Night !|Partly cloudy]( "Partly cloudy")
#
# The night temperature in Chennai today is 30°C with a wind speed of 18km/h.
#
# Clothing recommendation for Chennai
# -----------------------------------
#
# Tuesday, 20 May 2025
#
# !|Umbrella]( "Umbrella")
#
# Umbrella
#
# !|T-Shirt]( "T-Shirt")
#
# T-Shirt
#
# More about the weather in Chennai
#
# |Chennai 14 day weather](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=14)  |Long range weather for
# Chennai](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=long-range)  |Chennai weather in
# May](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=month&month=May)  |Chennai weather in
# June](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=month&month=June)  |Chennai
# Webcam](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=webcam)  |Weather
# tomorrow](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=tomorrow)  |Hotels in
# Chennai](https://www.weather25.com/asia/india/tamil-nadu/chennai?page=hotels)
#
# !|weather25.com]( "weather25.com")
#
# Chennai weather data is sourced from official meteorological authorities worldwide, ensuring accuracy and
# reliability.
#
# Popular Cities
#
# |› New York](https://www.weather25.com/north-america/usa/new-york) |›
# London](https://www.weather25.com/europe/united-kingdom/london) |›
# Sydney](https://www.weather25.com/oceania/australia/new-south-wales/sydney) |›
# Singapore](https://www.weather25.com/asia/singapore)
#
# Weather25.com
#
#  |› Terms and conditions](https://www.weather25.com/terms)   |› Privacy Policy](https://www.weather25.com/privacy)
# |› Contact](https://www.weather25.com/contact-us)
#
# Copyright © 2025, **weather25.com**
# [Step 4: Duration 1.49 seconds| Input tokens: 8,690 | Output tokens: 154]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'The weather in Chennai today is very hot with          │
# │ temperatures reaching 31°C. There is a 100% chance of rain, with light rain showers expected in the morning.    │
# │ The wind will blow between 8 Km/h to 18 Km/h. The sun will rise at 05:43 and set at 18:28, providing 10.5 hours │
# │ of sunlight.'}                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Final answer: The weather in Chennai today is very hot with temperatures reaching 31°C. There is a 100% chance of
# rain, with light rain showers expected in the morning. The wind will blow between 8 Km/h to 18 Km/h. The sun will
# rise at 05:43 and set at 18:28, providing 10.5 hours of sunlight.
# [Step 5: Duration 1.96 seconds| Input tokens: 14,840 | Output tokens: 257]
# The weather in Chennai today is very hot with temperatures reaching 31°C. There is a 100% chance of rain, with light rain showers expected in the morning. The wind will blow between 8 Km/h to 18 Km/h. The sun will rise at 05:43 and set at 18:28, providing 10.5 hours of sunlight.

# %%
from IPython.display import Image, display

display(Image(filename=result))
